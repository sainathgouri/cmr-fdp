# %%
pip install llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00
# ...

# %%
pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 19.9 MB/s eta 0:00:00
# ...

# %%
from llama_index.llms.groq import Groq

# %%
GROQ_API_KEY="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"

# %%
# !pip install --upgrade llama-index-llms-groq

# %%
llm=Groq(model="llama3-70b-8192",api_key="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")

# %%
response = llm.complete("Explain the importance of low latency")

# %%
print(response)
# Out:
# Low latency is crucial in various aspects of technology and communication because it directly impacts the performance, efficiency, and overall user experience. Here are some reasons why low latency is important:
#
# 1. **Real-time Interactivity**: Low latency enables real-time interactivity, which is essential for applications that require immediate responses, such as:
# 	* Online gaming: Fast response times ensure a seamless gaming experience, allowing players to react quickly to changing situations.
# 	* Video conferencing: Low latency ensures that video and audio are synchronized, enabling natural conversations and reducing frustration.
# 	* Virtual reality (VR) and augmented reality (AR): Low latency is critical for providing an immersive experience, as high latency can cause motion sickness and disorientation.
# 2. **Improved User Experience**: Low latency leads to a better user experience in various applications, including:
# ...

# %%
from llama_index.core.llms import ChatMessage
messages=[
    ChatMessage(
    role="System",Content="best programmer in machine learning"
),
          ChatMessage(role="user",content="what is your name"),
          ]
resp = llm.chat(messages)# Removed extra indent from this line
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-13-92bde777f52c> in <cell line: 0>()
#       1 from llama_index.core.llms import ChatMessage
#       2 messages=[
# ----> 3     ChatMessage(
#       4     role="System",Content="best programmer in machine learning"
#       5 ),
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/base/llms/types.py in __init__(self, content, **data)
#     204                 data["blocks"] = content
#     205
# --> 206         super().__init__(**data)
#     207
#     208     @model_validator(mode="after")
#
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py in __init__(self, **data)
#     212         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213         __tracebackhide__ = True
# ...

# %%
from llama_index.core.llms import ChatMessage
messages=[
  ChatMessage(
    role="system", Content="you are a pirate with a colorful personalty"
    ),
    ChatMessage(role="user",content="what is your name"),
]
resp = llm.chat(messages)

# %%
print(resp)
# Out:
# assistant: I don't have a personal name. I am an AI designed to assist and communicate with users in a helpful and informative way. I don't have a personal identity or consciousness, and I exist solely to provide information and answer questions to the best of my ability. You can think of me as a helpful tool or a knowledgeable assistant, but I don't have a name in the classical sense.

# %%
response=llm.stream_complete("Explain the importance of low latency")

# %%
for r in response:
    print(r.delta, end="\t")

# %%
pip install llama-index llama-index-embeddings-huggingface llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 06:07:36--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.02s
#
# 2025-03-13 06:07:37 (3.15 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2025-03-13 06:24:26--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.02s
#
# 2025-03-13 06:24:27 (3.36 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 06:29:58--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.02s
#
# 2025-03-13 06:29:58 (3.15 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
GROQ_API_KEY = "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"

# %%
llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author worked on two main things outside of school: writing and programming. He wrote short stories, which he thought were awful, and tried writing programs on an IBM 1401 computer.

# %%
#!wget -O data/abc.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %%
GROQ_API_KEY = "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"

# %%
llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("how to create table sailors")
print(response)
# Out:
# The query is asking about creating a table called "sailors", but the context information provided doesn't mention anything about creating tables or databases. The context is about the story of starting a company called Viaweb, which built online store software.
#
# However, based on the context, it seems that the author is familiar with programming and software development. To create a table called "sailors", you would typically use a SQL command like "CREATE TABLE sailors (...)" where the ellipsis represents the column definitions. But without more information about the specific database management system or the columns required, it's difficult to provide a more detailed answer.
